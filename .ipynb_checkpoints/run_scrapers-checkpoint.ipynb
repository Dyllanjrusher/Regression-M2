# %%
import college_nav_scraper_funcs as cnsf

# %%
driver = cnsf.load_webpage()

# %%
cns_data = cnsf.get_all_college_data(driver)
# Out:
# test
# Here
# ['Alabama A & M University', '6106', 20.0, 'City: Midsize', 100654, '90', 'Not applicable', '3% or less', '259', '95', 22, 14, 24, 62, 18.97]
# ['Alabama State University', '4413', 15.0, 'City: Midsize', 100724, '95', 'Not applicable', '3% or less', '231', '182', 33, 21, 17, 31, 20.27]
# ['Amridge University', '755', 12.0, 'City: Midsize', 100690, '100', 'Churches of Christ', '3% or less', '33', '0', 0, 0, 0, 0, 11.67]
# ['Athens State University', '3044', 15.0, 'Town: Fringe', 100812, None, 'Not applicable', '3% or less', '86', '107', 0, 0, 0, 0, 6.67]
# ['Auburn University', '30440', 19.0, 'City: Small', 100858, '72', 'Not applicable', '7%', '1,644', '234', 73, 32, 15, 159, 3.43]
# ['Auburn University at Montgomery', '5211', 17.0, 'City: Midsize', 100830, '98', 'Not applicable', '4%', '211', '145', 19, 27, 18, 31, 10.6]
# ['Birmingham-Southern College', '1268', 12.0, 'City: Midsize', 100937, '97', 'United Methodist', '11%', '96', '37', 18, 15, 0, 66, 5.27]
# ...

# %%
len(cns_data) #that took over 4 hours! better pickle it
# Out:
# 2469

# %%
header = ['name', 'student_pop', 'student_fac_ratio',
             'setting', 'IPEDS_ID', 'perc_aid', 'religious_aff',
             'perc_reg_disabled', 'full_time_fac', 'part_time_fac',
             'criminal_offenses', 'vawa_offenses', 'arrests', 'disciplinary_actions',
             'avg_default_rate']

# %%
import pandas as pd
cns_df = pd.DataFrame(cns_data, columns=header)

# %%
cns_df.describe()
# Out:
#        student_fac_ratio       IPEDS_ID  criminal_offenses  vawa_offenses  \
# count        2427.000000    2469.000000        2340.000000    2340.000000
# mean           13.984343  232178.888214          18.486752       7.413675
# std             6.027124  113122.814308          20.609530       9.029702
# min             1.000000  100654.000000           0.000000       0.000000
# 25%            10.000000  157076.000000           1.000000       0.000000
# 50%            13.000000  198969.000000          10.000000       4.000000
# 75%            17.000000  236258.000000          31.000000      12.000000
# max            78.000000  494807.000000          93.000000      50.000000
#
#            arrests  disciplinary_actions  avg_default_rate
# count  2340.000000           2340.000000       2244.000000
# mean      7.944872             33.894872          7.837086
# std      10.532466             40.973313          5.481970
# min       0.000000              0.000000          0.000000
# ...

# %%
cns_df.info() #nice, not too many nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2469 entries, 0 to 2468
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  2469 non-null   object
#  1   student_pop           2439 non-null   object
#  2   student_fac_ratio     2427 non-null   float64
#  3   setting               2468 non-null   object
#  4   IPEDS_ID              2469 non-null   int64
#  5   perc_aid              2284 non-null   object
#  6   religious_aff         2469 non-null   object
#  7   perc_reg_disabled     2460 non-null   object
#  8   full_time_fac         2312 non-null   object
#  9   part_time_fac         2312 non-null   object
#  10  criminal_offenses     2340 non-null   float64
#  11  vawa_offenses         2340 non-null   float64
#  12  arrests               2340 non-null   float64
#  13  disciplinary_actions  2340 non-null   float64
#  14  avg_default_rate      2244 non-null   float64
# ...

# %%
cns_df.to_pickle('cns_df.pkl')

# %%
test = pd.read_pickle('cns_df.pkl')#gotta make sure i did this correctly

# %%
test.head()
# Out:
#                        name student_pop  student_fac_ratio        setting  \
# 0  Alabama A & M University        6106               20.0  City: Midsize
# 1  Alabama State University        4413               15.0  City: Midsize
# 2        Amridge University         755               12.0  City: Midsize
# 3   Athens State University        3044               15.0   Town: Fringe
# 4         Auburn University       30440               19.0    City: Small
#
#    IPEDS_ID perc_aid       religious_aff perc_reg_disabled full_time_fac  \
# 0    100654       90      Not applicable        3% or less           259
# 1    100724       95      Not applicable        3% or less           231
# 2    100690      100  Churches of Christ        3% or less            33
# 3    100812     None      Not applicable        3% or less            86
# 4    100858       72      Not applicable                7%         1,644
#
#   part_time_fac  criminal_offenses  vawa_offenses  arrests  \
# ...
