# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re

# %%
def get_urls():
    '''returns college results urls and ids'''
    cns_df = pd.read_pickle('cns_df.pkl')
    ids = cns_df['IPEDS_ID'].values
    urls = []
    base = 'http://www.collegeresults.org/collegeprofile.aspx?institutionid='
    for IPEDS_ID in ids:
        urls.append(base + str(IPEDS_ID))
    return urls, ids

# %%
def get_soup(url):
    '''returns soup, if page not there, returns None'''
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml')
    if 'Error occurred while loading college profile' in str(soup.text):
        return None
    return soup

# %%
def get_data(soup, header, data):
    for txt in header:
        data.append(soup.find('td', text=txt).next_sibling.next_sibling.text)
    return data

# %%
def get_all_data():
    
    header = ['Endowment Assets', 'Minority-Serving Institution', 'Average High School GPA Among College Freshmen',
       'Sector', 'Median ACT Composite', 'Percent Admitted','In-State Tuition and Fees',
       'Out-of-State Tuition and Fees', 'Average Net Price After Grants', 'Median earnings 10 years after entry',
       'Median debt of completers', '% Pell Recipients Among Freshman', '% Black', '% Latino', 
       '% Native American', '% Native Hawaiian/Pacific Islander', '% Asian', '% White', '% Two or More Races',
       '% Other', '% Noresident Aliens', '% Female', '% Male', '% Age 25 and Over',
       '% Part-time', 'First-year retention rate', 'Four-year graduation rate', 'Five-year graduation rate',
             'Six-year graduation rate']
    college_results_data = []
    urls, ids = get_urls()
    i = 1
    for url, ID in zip(urls, ids):
        soup = get_soup(url)
        if soup == None:
            print(url, ID)
            continue
        data = [ID]
        college_results_data.append(get_data(soup, header, data))
        if i%10 == 0:
            print('page {} done'.format(i))
        i += 1
    return college_results_data

# %%
college_results_data = get_all_data()
#only 1843 of 2468 seemed to be valid urls:/
# Out:
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=100690 100690
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=100812 100812
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=101453 101453
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=101365 101365
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=449348 449348
# page 10 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=366535 366535
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=450377 450377
# page 20 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=102395 102395
# page 30 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=434584 434584
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=494171 494171
# page 40 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=404055 404055
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=438179 438179
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=110219 110219
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=454245 454245
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=105297 105297
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=436614 436614
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=105367 105367
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=464226 464226
# page 50 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=487296 487296
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=492069 492069
# page 60 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=458885 458885
# page 70 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=106263 106263
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=493725 493725
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=488031 488031
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=110468 110468
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=490081 490081
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=433004 433004
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=457299 457299
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=109350 109350
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=245838 245838
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=245847 245847
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=444325 444325
# page 80 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=109819 109819
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=461643 461643
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=475635 475635
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=262086 262086
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=433420 433420
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=110918 110918
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=478634 478634
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=111045 111045
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=110316 110316
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=485546 485546
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=483586 483586
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=486488 486488
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=480781 480781
# page 90 done
# page 100 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=460075 460075
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=433013 433013
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=489353 489353
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=111966 111966
# page 110 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=113236 113236
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=113582 113582
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=124487 124487
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=114433 114433
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=114390 114390
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=114716 114716
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=372073 372073
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=449384 449384
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=115083 115083
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=481058 481058
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=459213 459213
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=457086 457086
# page 120 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=486965 486965
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=116226 116226
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=116712 116712
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=454786 454786
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=117557 117557
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=117636 117636
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=490124 490124
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=446385 446385
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=474863 474863
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=476595 476595
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=119058 119058
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=118912 118912
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=118976 118976
# page 130 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=444130 444130
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=120166 120166
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=422695 422695
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=120768 120768
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=120838 120838
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=120698 120698
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=439871 439871
# page 140 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=490878 490878
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=260789 260789
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=432384 432384
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=480204 480204
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=121275 121275
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=490045 490045
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=121886 121886
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=122296 122296
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=493512 493512
# http://www.collegeresults.org/collegeprofile.aspx?institutionid
done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=491297 491297
# page 1800 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=240736 240736
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=439862 439862
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=376695 376695
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=440651 440651
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=241331 241331
# page 1810 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=484835 484835
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=241304 241304
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=404806 404806
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=469416 469416
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=376321 376321
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=494278 494278
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=494287 494287
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=492476 492476
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=241951 241951
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=242112 242112
# page 1820 done
# page 1830 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243081 243081
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=494807 494807
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=430670 430670
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=376385 376385
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243568 243568
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=441690 441690
# page 1840 done
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=241614 241614
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243115 243115
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243133 243133
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243142 243142
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243151 243151
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243179 243179
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243203 243203
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243212 243212
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243221 243221
# http://www.collegeresults.org/collegeprofile.aspx?institutionid=243188 243188

# %%
college_results_data[0]
# Out:
# [100654,
#  '-',
#  'Historically Black',
#  '-',
#  'Public',
#  '17.5 (25th - 75th percentile = 16 - 19)',
#  '87.4%',
#  '$9,366',
#  '$17,496',
#  '$15,812',
#  '$31,000',
#  '$32,750',
#  '71.1%',
#  '91.3%',
#  '0.7%',
#  '0.2%',
#  '0.2%',
#  '0.2%',
#  '2.4%',
#  '4.1%',
#  '0.8%',
#  '0.7%',
#  '56.7%',
#  '43.3%',
#  '7.3%',
#  '8.6%',
#  '58%',
#  '3.8%',
#  '16.7%',
#  '24.0%']

# %%
header = ['IPEDS_ID', 'Endowment Assets', 'Minority-Serving Institution', 'Average High School GPA Among College Freshmen',
       'Sector', 'Median ACT Composite', 'Percent Admitted','In-State Tuition and Fees',
       'Out-of-State Tuition and Fees', 'Average Net Price After Grants', 'Median earnings 10 years after entry',
       'Median debt of completers', '% Pell Recipients Among Freshman', '% Black', '% Latino', 
       '% Native American', '% Native Hawaiian/Pacific Islander', '% Asian', '% White', '% Two or More Races',
       '% Other', '% Noresident Aliens', '% Female', '% Male', '% Age 25 and Over',
       '% Part-time', 'First-year retention rate', 'Four-year graduation rate', 'Five-year graduation rate',
             'Six-year graduation rate']
cr_df = pd.DataFrame(college_results_data, columns=header)

# %%
cr_df.head()
# Out:
#    IPEDS_ID Endowment Assets Minority-Serving Institution  \
# 0    100654                -           Historically Black
# 1    100724     $100,905,446           Historically Black
# 2    100858     $728,995,077               Not Applicable
# 3    100830      $50,109,520               Not Applicable
# 4    100937      $53,528,445               Not Applicable
#
#   Average High School GPA Among College Freshmen                  Sector  \
# 0                                              -                  Public
# 1                                           2.80                  Public
# 2                                           3.85                  Public
# 3                                           3.30                  Public
# 4                                           3.48  Private not-for-profit
#
#                       Median ACT Composite Percent Admitted  \
# 0  17.5 (25th - 75th percentile = 16 - 19)            87.4%
# 1  17.0 (25th - 75th percentile = 15 - 19)            45.9%
# 2  27.0 (25th - 75th percentile = 24 - 30)            80.5%
# 3  21.5 (25th - 75th percentile = 19 - 24)            76.6%
# 4  25.5 (25th - 75th percentile = 23 - 28)            48.4%
#
#   In-State Tuition and Fees Out-of-State Tuition and Fees  \
# 0                    $9,366                       $17,496
# 1                    $9,220                       $16,156
# 2                   $10,696                       $28,840
# 3                    $9,640                       $20,710
# 4                   $34,448                       $34,448
#
#   Average Net Price After Grants  ... % Other % Noresident Aliens % Female  \
# 0                        $15,812  ...    0.8%                0.7%    56.7%
# 1                        $12,327  ...    2.5%                1.6%    62.3%
# 2                        $22,613  ...    4.2%                3.6%    49.7%
# 3                        $15,047  ...    5.3%                4.8%    64.7%
# 4                        $23,846  ...    0.2%                0.0%    50.9%
#
#   % Male % Age 25 and Over % Part-time First-year retention rate  \
# 0  43.3%              7.3%        8.6%                       58%
# 1  37.7%              7.9%        7.6%                       63%
# 2  50.3%              3.0%       10.0%                       91%
# 3  35.3%             17.7%       27.6%                       67%
# 4  49.1%              1.3%        0.7%                       82%
#
#   Four-year graduation rate Five-year graduation rate Six-year graduation rate
# 0                      3.8%                     16.7%                    24.0%
# 1                     11.3%                     23.1%                    27.7%
# 2                     49.1%                     72.9%                    76.6%
# 3                      8.8%                     21.7%                    27.6%
# 4                     57.8%                     64.3%                    66.1%
#
# [5 rows x 30 columns]

# %%
#### cr_df.info()

# %%
cr_df.to_pickle('cr_df.pkl')

# %%
cr_df[cr_df['Median earnings 10 years after entry'] != '-'].head()
# Out:
#    IPEDS_ID Endowment Assets Minority-Serving Institution  \
# 0    100654                -           Historically Black
# 1    100724     $100,905,446           Historically Black
# 2    100858     $728,995,077               Not Applicable
# 3    100830      $50,109,520               Not Applicable
# 4    100937      $53,528,445               Not Applicable
#
#   Average High School GPA Among College Freshmen                  Sector  \
# 0                                              -                  Public
# 1                                           2.80                  Public
# 2                                           3.85                  Public
# 3                                           3.30                  Public
# 4                                           3.48  Private not-for-profit
#
#                       Median ACT Composite Percent Admitted  \
# 0  17.5 (25th - 75th percentile = 16 - 19)            87.4%
# 1  17.0 (25th - 75th percentile = 15 - 19)            45.9%
# 2  27.0 (25th - 75th percentile = 24 - 30)            80.5%
# 3  21.5 (25th - 75th percentile = 19 - 24)            76.6%
# 4  25.5 (25th - 75th percentile = 23 - 28)            48.4%
#
#   In-State Tuition and Fees Out-of-State Tuition and Fees  \
# 0                    $9,366                       $17,496
# 1                    $9,220                       $16,156
# 2                   $10,696                       $28,840
# 3                    $9,640                       $20,710
# 4                   $34,448                       $34,448
#
#   Average Net Price After Grants  ... % Other % Noresident Aliens % Female  \
# 0                        $15,812  ...    0.8%                0.7%    56.7%
# 1                        $12,327  ...    2.5%                1.6%    62.3%
# 2                        $22,613  ...    4.2%                3.6%    49.7%
# 3                        $15,047  ...    5.3%                4.8%    64.7%
# 4                        $23,846  ...    0.2%                0.0%    50.9%
#
#   % Male % Age 25 and Over % Part-time First-year retention rate  \
# 0  43.3%              7.3%        8.6%                       58%
# 1  37.7%              7.9%        7.6%                       63%
# 2  50.3%              3.0%       10.0%                       91%
# 3  35.3%             17.7%       27.6%                       67%
# 4  49.1%              1.3%        0.7%                       82%
#
#   Four-year graduation rate Five-year graduation rate Six-year graduation rate
# 0                      3.8%                     16.7%                    24.0%
# 1                     11.3%                     23.1%                    27.7%
# 2                     49.1%                     72.9%                    76.6%
# 3                      8.8%                     21.7%                    27.6%
# 4                     57.8%                     64.3%                    66.1%
#
# [5 rows x 30 columns]

# %%
mask = (cr_df['Median earnings 10 years after entry'] != '-')
cr_df[mask][['Median earnings 10 years after entry', 'IPEDS_ID']]
# Out:
#      Median earnings 10 years after entry  IPEDS_ID
# 0                                 $31,000    100654
# 1                                 $27,700    100724
# 2                                 $48,800    100858
# 3                                 $33,300    100830
# 4                                 $46,700    100937
# ...                                   ...       ...
# 1836                              $19,700    243601
# 1837                              $19,600    241225
# 1838                              $20,200    243443
# 1839                              $29,800    243577
# 1842                              $32,000    243665
#
# [1737 rows x 2 columns]
